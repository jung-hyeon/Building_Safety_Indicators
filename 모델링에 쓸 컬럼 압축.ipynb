# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/iterat1on/Downloads/final.csv")
pd.set_option('display.max_columns', None)
df
# Out:
#        사망인명피해수  분기구분  화재발생시  현장소방서거리  현장안전센터거리  현장소방지역대거리 발화요인대분류명 시설장소중분류명  \
# 0            0     1      0        4         3        0.0   전기적 요인     단독주택
# 1            0     1     15        4         2        0.0      부주의    일상서비스
# 2            0     1     20        5         1        0.0      부주의      음식점
# 3            0     1     10        4         1        0.0      부주의      음식점
# 4            0     1      3        5         3        0.0      부주의     단독주택
# ...        ...   ...    ...      ...       ...        ...      ...      ...
# 21248        0     4     18        2         1        0.0      부주의     공동주택
# 21249        2     1      8        3         2        0.0   화학적 요인     공동주택
# 21250        0     1     22        4         1        0.0   전기적 요인     단독주택
# 21251        0     4     12        4         2        0.0      부주의     공동주택
# 21252        0     3     13        2         1        0.0       미상    연구/학원
#
# ...

# %%
df.방화관리대상여부.value_counts()
# Out:
# N    14672
# Y     6581
# Name: 방화관리대상여부, dtype: int64

# %%
def dummy(x) :
    if x == "N" :
        return 1
    else :
        return 0

# %%
df.방화관리대상여부 = df.방화관리대상여부.apply(lambda x : dummy(x))
df
# Out:
#        사망인명피해수  분기구분  화재발생시  현장소방서거리  현장안전센터거리  현장소방지역대거리 발화요인대분류명 시설장소중분류명  \
# 0            0     1      0        4         3        0.0   전기적 요인     단독주택
# 1            0     1     15        4         2        0.0      부주의    일상서비스
# 2            0     1     20        5         1        0.0      부주의      음식점
# 3            0     1     10        4         1        0.0      부주의      음식점
# 4            0     1      3        5         3        0.0      부주의     단독주택
# ...        ...   ...    ...      ...       ...        ...      ...      ...
# 21248        0     4     18        2         1        0.0      부주의     공동주택
# 21249        2     1      8        3         2        0.0   화학적 요인     공동주택
# 21250        0     1     22        4         1        0.0   전기적 요인     단독주택
# 21251        0     4     12        4         2        0.0      부주의     공동주택
# 21252        0     3     13        2         1        0.0       미상    연구/학원
#
# ...

# %%
df.drop(["발화요인대분류명", "시설장소중분류명", "분기구분", "화재발생시", "현장소방지역대거리", "현장소방서거리", "평균 상대습도(%)", "시간단위습도"], axis = 1, inplace = True)
df
# Out:
#        사망인명피해수  현장안전센터거리  방화관리대상여부  시간단위기온  시간단위풍속  시간단위풍향  시간단위가시거리  재산피해액  \
# 0            0         3         0     0.2     2.2    20.0       491  13391
# 1            0         2         1     9.3     1.9   270.0       703     35
# 2            0         1         1    -4.2     1.8   250.0      2000    308
# 3            0         1         0    -4.4     4.5   270.0       558    184
# 4            0         3         1     1.5     5.9   270.0       634    877
# ...        ...       ...       ...     ...     ...     ...       ...    ...
# 21248        0         1         1     7.1     2.2   290.0      1773     11
# 21249        2         2         1    -0.3     2.0    20.0      2000   4000
# 21250        0         1         1     4.7     0.6    90.0       137     58
# 21251        0         2         0     2.3     1.1    50.0       950     18
# 21252        0         1         0    33.9     1.7   140.0      2000  38353
#
#             실효습도    전기사용량(KWh)    가스사용량(KWh)
# ...

# %%
df.corr()
# Out:
#              사망인명피해수  현장안전센터거리  방화관리대상여부    시간단위기온    시간단위풍속    시간단위풍향  \
# 사망인명피해수     1.000000  0.004142 -0.010605 -0.009956 -0.009299 -0.011351
# 현장안전센터거리    0.004142  1.000000 -0.020530 -0.014257  0.011365  0.010800
# 방화관리대상여부   -0.010605 -0.020530  1.000000 -0.005854  0.002218 -0.007936
# 시간단위기온     -0.009956 -0.014257 -0.005854  1.000000 -0.005730 -0.130948
# 시간단위풍속     -0.009299  0.011365  0.002218 -0.005730  1.000000  0.281294
# 시간단위풍향     -0.011351  0.010800 -0.007936 -0.130948  0.281294  1.000000
# 시간단위가시거리    0.004449  0.012690 -0.001007  0.002301  0.163370  0.042613
# 재산피해액       0.011215 -0.012113 -0.011187  0.000712 -0.004338 -0.010510
# 실효습도       -0.004306 -0.016853  0.003635  0.491208 -0.036246 -0.160067
# 전기사용량(KWh)  0.006439  0.102182 -0.213744 -0.005902  0.011618  0.005358
# 가스사용량(KWh)  0.021558  0.072021 -0.179852 -0.005139 -0.004631 -0.000559
#
#             시간단위가시거리     재산피해액      실효습도  전기사용량(KWh)  가스사용량(KWh)
# ...

# %%
df[df.방화관리대상여부 == 0].사망인명피해수.value_counts()
# Out:
# 0     6313
# 1      195
# 2       34
# 3       17
# 4        9
# 5        3
# 6        2
# 8        2
# 15       1
# 10       1
# 33       1
# 9        1
# 32       1
# 14       1
# Name: 사망인명피해수, dtype: int64

# %%
df[df.방화관리대상여부 == 1].사망인명피해수.value_counts()
# Out:
# 0     13976
# 1       556
# 2        86
# 3        28
# 4        14
# 5         8
# 7         1
# 11        1
# 10        1
# 18        1
# Name: 사망인명피해수, dtype: int64

# %%
df.drop(["방화관리대상여부", "시간단위풍향"], axis = 1, inplace = True)
df
# Out:
#        사망인명피해수  현장안전센터거리  시간단위기온  시간단위풍속  시간단위가시거리  재산피해액       실효습도  \
# 0            0         3     0.2     2.2       491  13391  54.273750
# 1            0         2     9.3     1.9       703     35  49.554054
# 2            0         1    -4.2     1.8      2000    308  31.607682
# 3            0         1    -4.4     4.5       558    184  50.355768
# 4            0         3     1.5     5.9       634    877  43.742292
# ...        ...       ...     ...     ...       ...    ...        ...
# 21248        0         1     7.1     2.2      1773     11  53.538975
# 21249        2         2    -0.3     2.0      2000   4000  48.487317
# 21250        0         1     4.7     0.6       137     58  55.215504
# 21251        0         2     2.3     1.1       950     18  53.850522
# 21252        0         1    33.9     1.7      2000  38353  61.490694
#
#          전기사용량(KWh)    가스사용량(KWh)
# 0      18096.210463  11774.100170
# 1      18096.210463  11774.100170
# ...

# %%
df
# Out:
#        사망인명피해수  현장안전센터거리  시간단위기온  시간단위풍속  시간단위가시거리  재산피해액       실효습도  \
# 0            0         3     0.2     2.2       491  13391  54.273750
# 1            0         2     9.3     1.9       703     35  49.554054
# 2            0         1    -4.2     1.8      2000    308  31.607682
# 3            0         1    -4.4     4.5       558    184  50.355768
# 4            0         3     1.5     5.9       634    877  43.742292
# ...        ...       ...     ...     ...       ...    ...        ...
# 21248        0         1     7.1     2.2      1773     11  53.538975
# 21249        2         2    -0.3     2.0      2000   4000  48.487317
# 21250        0         1     4.7     0.6       137     58  55.215504
# 21251        0         2     2.3     1.1       950     18  53.850522
# 21252        0         1    33.9     1.7      2000  38353  61.490694
#
#          전기사용량(KWh)    가스사용량(KWh)
# 0      18096.210463  11774.100170
# 1      18096.210463  11774.100170
# ...

# %%
df.corr()
# Out:
#              사망인명피해수  현장안전센터거리    시간단위기온    시간단위풍속  시간단위가시거리     재산피해액  \
# 사망인명피해수     1.000000  0.004142 -0.009956 -0.009299  0.004449  0.011215
# 현장안전센터거리    0.004142  1.000000 -0.014257  0.011365  0.012690 -0.012113
# 시간단위기온     -0.009956 -0.014257  1.000000 -0.005730  0.002301  0.000712
# 시간단위풍속     -0.009299  0.011365 -0.005730  1.000000  0.163370 -0.004338
# 시간단위가시거리    0.004449  0.012690  0.002301  0.163370  1.000000  0.005243
# 재산피해액       0.011215 -0.012113  0.000712 -0.004338  0.005243  1.000000
# 실효습도       -0.004306 -0.016853  0.491208 -0.036246 -0.211445 -0.002640
# 전기사용량(KWh)  0.006439  0.102182 -0.005902  0.011618  0.010498 -0.002724
# 가스사용량(KWh)  0.021558  0.072021 -0.005139 -0.004631  0.006026 -0.002572
#
#                 실효습도  전기사용량(KWh)  가스사용량(KWh)
# 사망인명피해수    -0.004306    0.006439    0.021558
# 현장안전센터거리   -0.016853    0.102182    0.072021
# 시간단위기온      0.491208   -0.005902   -0.005139
# 시간단위풍속     -0.036246    0.011618   -0.004631
# ...

# %%
df.to_csv("data_final.csv", index = False)

# %% [markdown]
# 여기서 부턴 안돌림

# %%
from sklearn.preprocessing import StandardScaler

# 두 가지 feature를 대상

data = df.copy()

# 정규화 진행
scaler = StandardScaler()
data_scale = scaler.fit_transform(data)

# %%
data_scale = pd.DataFrame(data_scale, columns = df.columns)
data_scale
# Out:
#         사망인명피해수      분기구분     화재발생시   현장소방서거리  현장안전센터거리  현장소방지역대거리  방화관리대상여부  \
# 0     -0.132793 -1.343030 -1.934584  0.452460  1.559581  -0.067455 -1.493134
# 1     -0.132793 -1.343030  0.338158  0.452460  0.428017  -0.067455  0.669732
# 2     -0.132793 -1.343030  1.095738  1.030944 -0.703547  -0.067455  0.669732
# 3     -0.132793 -1.343030 -0.419423  0.452460 -0.703547  -0.067455 -1.493134
# 4     -0.132793 -1.343030 -1.480036  1.030944  1.559581  -0.067455  0.669732
# ...         ...       ...       ...       ...       ...        ...       ...
# 21248 -0.132793  1.347714  0.792706 -0.704508 -0.703547  -0.067455  0.669732
# 21249  3.733294 -1.343030 -0.722455 -0.126024  0.428017  -0.067455  0.669732
# 21250 -0.132793 -1.343030  1.398771  0.452460 -0.703547  -0.067455  0.669732
# 21251 -0.132793  1.347714 -0.116391  0.452460  0.428017  -0.067455 -1.493134
# 21252 -0.132793  0.450799  0.035125 -0.704508 -0.703547  -0.067455 -1.493134
#
# ...

# %%
from sklearn.cluster import KMeans

x = [] 
y = []  

for k in range(1, 10):
    kmeans = KMeans(n_clusters = k)
    kmeans.fit(data_scale)
    
    x.append(k)
    y.append(kmeans.inertia_)

# %%
import matplotlib.pyplot as plt
plt.plot(x, y);

# %% [markdown]
# cluster 4 elbow point

# %%
kmeans = KMeans(n_clusters=2, random_state=0)
clusters = kmeans.fit(data_scale)
data_scale['clusters'] = clusters.labels_
data_scale
# Out:
#         사망인명피해수      분기구분     화재발생시   현장소방서거리  현장안전센터거리  현장소방지역대거리  방화관리대상여부  \
# 0     -0.132793 -1.343030 -1.934584  0.452460  1.559581  -0.067455 -1.493134
# 1     -0.132793 -1.343030  0.338158  0.452460  0.428017  -0.067455  0.669732
# 2     -0.132793 -1.343030  1.095738  1.030944 -0.703547  -0.067455  0.669732
# 3     -0.132793 -1.343030 -0.419423  0.452460 -0.703547  -0.067455 -1.493134
# 4     -0.132793 -1.343030 -1.480036  1.030944  1.559581  -0.067455  0.669732
# ...         ...       ...       ...       ...       ...        ...       ...
# 21248 -0.132793  1.347714  0.792706 -0.704508 -0.703547  -0.067455  0.669732
# 21249  3.733294 -1.343030 -0.722455 -0.126024  0.428017  -0.067455  0.669732
# 21250 -0.132793 -1.343030  1.398771  0.452460 -0.703547  -0.067455  0.669732
# 21251 -0.132793  1.347714 -0.116391  0.452460  0.428017  -0.067455 -1.493134
# 21252 -0.132793  0.450799  0.035125 -0.704508 -0.703547  -0.067455 -1.493134
#
# ...

# %%
data_scale.clusters.value_counts()
# Out:
# 1    10663
# 0    10590
# Name: clusters, dtype: int64
